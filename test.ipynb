# %%
import xarray
ds = xarray.load_dataset(r"C:\Users\c.winger\AppData\Local\datatools\datatools\data\http\opendata.dwd.de\climate_environment\cdc\grids_germany\multi_annual\wind_parameters\project_quwind100\ref_1981_2010\re_ff_mean_year_201902280000_l100.nc")

# %%
ds.FF.plot()

# %%
ds.X[0]
# Out:
# <xarray.DataArray 'X' ()>
# array(4030050)
# Coordinates:
#     X        int32 4030050
# Attributes:
#     units:      m
#     long_name:  x coordinate of projection

# %%
ds.Y[0]
# Out:
# <xarray.DataArray 'Y' ()>
# array(2680050)
# Coordinates:
#     Y        int32 2680050
# Attributes:
#     units:      m
#     long_name:  y coordinate of projection

# %%
y0=2680000
x0=4030000
dx=dy=100

# %%
# -a_ullr ulx uly lrx lry
-a_ullr 4030000 3560000 4680000 2680000
print(f"{ds.X[0].item()-50} {ds.Y[-1].item()+50} {ds.X[-1].item()+50} {ds.Y[0].item()-50}")
# Out:
# 4030000 3560000 4680000 2680000
